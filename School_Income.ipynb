# %%
import scipy as sc
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
education = "~/Education.xlsx"
ed2 = "~/Ed2.xlsx"
income = "~/income.xlsx"
mbe = "~/MbE.xlsx"
df = pd.read_excel(education)
df2 = pd.read_excel(ed2)
df3 = pd.read_excel(income)
df4 = pd.read_excel(mbe)

# %%
df
# Out:
#                Location                  Education  Population
# 0                Ward 7                High School       30405
# 1                Ward 8  Bachelor's Degree & above        8627
# 2  District of Columbia                     Others        6179

# %%
#x = df["Location"]
labels = df["Education"]
data = df["Population"]
#h = df2["Ward 7, DC"]



#define Seaborn color palette to use
colors = sns.color_palette('pastel')[0:5]

#create pie chart
plt.title("Ward 8 Education")
plt.pie(data, labels = labels, colors = colors, autopct='%.0f%%')
plt.show()

# %%
#x = df["Location"]
labels = df2["Education"]
data = df2["Population"]
#h = df2["Ward 7, DC"]



#define Seaborn color palette to use
colors = sns.color_palette('pastel')[0:5]

#create pie chart
plt.title("Ward 7 Education")
plt.pie(data, labels = labels, colors = colors, autopct='%.0f%%')
plt.show()

# %%
#x = df["Location"]
labels = df4["Education"]
data = df4["Median Earnings"]
#h = df2["Ward 7, DC"]

# Define data for the chart
categories = df4["Education"]
values = df4["Median Earnings"]



fig, ax = plt.subplots(figsize=(8, 6))
ax.barh(categories, values)

# Add chart title and axis labels
ax.set_title('DoC Earnings by Education level')


#plt.xticks(rotation=45)

# Display the chart
plt.show()
